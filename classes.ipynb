# %%
class Carro:
    velMax=0
    ligado=False
    cor=" "
    def __init__(self,m,v,l,c):
        self.modelo=m
        self.velMax=v 
        self.ligado=l
        self.cor=c    
    def mostrar(self): 
        print(" Modelo...........: " ,self.modelo )
        print(" Velocidade máxima: " ,self.velMax )
        print(" Cor:.............. " ,self.cor )
        estado="Sim" if self.ligado  else "Nao"
        print(" Ligado:........... " ,estado)
        print("................................")    
    def ligar(self):
        self.ligado=True
    def desligado(self):
        self.desligado=False
    def andar(self):
        if(self.ligado):
            print("Andando")
        else:
            print("Desligado")
                                           	        	
c1=Carro("focus",300,False,"Preto")
c2=Carro("Fusion",320,False,"Branco")
c3=Carro("Fiesta",250,False,"Vermelho")

c1.ligar()
c1.mostrar()
c2.mostrar()
c3.mostrar()

c1.andar()
c2.andar()
# Out:
#  Modelo...........:  focus
#  Velocidade máxima:  300
#  Cor:..............  Preto
#  Ligado:...........  Sim
# ................................
#  Modelo...........:  Fusion
#  Velocidade máxima:  320
#  Cor:..............  Branco
#  Ligado:...........  Nao
# ................................
#  Modelo...........:  Fiesta
#  Velocidade máxima:  250
#  Cor:..............  Vermelho
#  Ligado:...........  Nao
# ................................
# Andando
# Desligado
